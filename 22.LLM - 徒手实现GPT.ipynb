# %% [markdown]
# # 徒手实现 GPT
#
# 来自视频 [徒手实现GPT：其实真的很简单](https://www.bilibili.com/video/BV1Hz421q7ks)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from datasets import load_dataset
import matplotlib.pyplot as plt
# %matplotlib inline


# 如果使用CPU，需要非常长的时间，建议减少模型规模来加快速度（比如n_layer）

# %%
# 一些超参数
emb_size = 128
head_size = 8
n_layer = 12
sequence_len = 64
learning_rate = 1e-3
eval_iters = 20
batch_size = 500
# 如果有GPU，该脚本将使用GPU进行计算
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
datasets = load_dataset('json', data_files='./datasets/python/final/jsonl/train/*.jsonl.gz')
datasets = datasets['train'].filter(lambda x: 'apache/spark' in x['repo'])


class CharTokenizer:

    def __init__(self, data, end_ind=0):
        # data: list[str]
        # 得到所有的字符
        chars = sorted(list(set(''.join(data))))
        self.char2ind = {s: i + 1 for i, s in enumerate(chars)}
        self.char2ind['<|e|>'] = end_ind
        self.ind2char = {v: k for k, v in self.char2ind.items()}
        self.end_ind = end_ind

    def encode(self, x):
        # x: str
        return [self.char2ind[i] for i in x]

    def decode(self, x):
        # x: int or list[x]
        if isinstance(x, int):
            return self.ind2char[x]
        return [self.ind2char[i] for i in x]


tokenizer = CharTokenizer(datasets['original_string'])
test_str = 'def f(x):'
re = tokenizer.encode(test_str)
print(re)
''.join(tokenizer.decode(range(len(tokenizer.char2ind))))
# Out:
# [70, 71, 72, 2, 72, 10, 90, 11, 28]
# '<|e|>\n !"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~ö'

# %%
def process(data, tokenizer, sequence_len=sequence_len):
    text = data['original_string']
    # text is list[str]
    inputs, labels = [], []
    for t in text:
        enc = tokenizer.encode(t)
        enc += [tokenizer.end_ind]
        # 有bug，无法处理长度过小的数据
        for i in range(len(enc) - sequence_len):
            inputs.append(enc[i: i + sequence_len])
            labels.append(enc[i + 1: i + 1 + sequence_len])
    return {'inputs': inputs, 'labels': labels}


# 将数据分为训练集和测试集
tokenized = datasets.train_test_split(test_size=0.1, seed=1024, shuffle=True)

f = lambda x: process(x, tokenizer)
tokenized = tokenized.map(f, batched=True, remove_columns=datasets.column_names)
tokenized.set_format(type='torch', device=device)

# %%
train_loader = DataLoader(tokenized['train'], batch_size=batch_size, shuffle=True)
test_loader = DataLoader(tokenized['test'], batch_size=batch_size, shuffle=True)
next(iter(train_loader))
# Out:
# {'inputs': tensor([[67, 78, 78,  ..., 78, 87, 79],
#          [84, 77, 53,  ...,  2,  2,  2],
#          [11, 94, 54,  ...,  2,  2,  2],
#          ...,
#          [82, 65, 68,  ..., 71, 82, 86],
#          [ 2, 85, 71,  ...,  2,  2,  2],
#          [ 2,  2,  2,  ...,  2, 67,  2]], device='cuda:0'),
#  'labels': tensor([[78, 78, 81,  ..., 87, 79, 80],
#          [77, 53, 71,  ...,  2,  2,  2],
#          [94, 54, 84,  ...,  2,  2, 19],
#          ...,
#          [65, 68, 91,  ..., 82, 86, 75],
#          [85, 71, 78,  ...,  2,  2, 72],
#          [ 2,  2,  2,  ..., 67,  2, 70]], device='cuda:0')}

# %%
@torch.no_grad()
def generate(model, context, tokenizer, max_new_tokens=300):
    # context: (1, T)
    #out = []
    out = context.tolist()[0]
    model.eval()
    for _ in range(max_new_tokens):
        # 由于注意力机制的长度限制，截断背景
        logits = model(context[:, -sequence_len:])
        probs = F.softmax(logits[:, -1, :], dim=-1)  # (1, 98)
        # 随机生成文本
        ix = torch.multinomial(probs, num_samples=1)  # (1, 1)
        # 更新背景
        context = torch.concat((context, ix), dim=-1)
        out.append(ix.item())
        if out[-1] == tokenizer.end_ind:
            break
    model.train()
    return out

# %%
def estimate_loss(model):
    re = {}
    # 将模型切换至评估模式
    model.eval()
    re['train'] = _loss(model, train_loader)
    re['test'] = _loss(model, test_loader)
    # 将模型切换至训练模式
    model.train()
    return re


@torch.no_grad()
def _loss(model, data_loader):
    """
    计算模型在不同数据集下面的评估指标
    """
    loss = []
    data_iter = iter(data_loader)
    # 随机使用多个批量数据来预估模型效果
    for k in range(eval_iters):
        data = next(data_iter, None)
        if data is None:
            data_iter = iter(data_loader)
            data = next(data_iter, None)
        inputs, labels = data['inputs'], data['labels']  # (B, T)
        logits = model(inputs)  # (B, T, vs)
        # 请参考官方文档
        loss.append(F.cross_entropy(logits.transpose(-2, -1), labels).item())
    return torch.tensor(loss).mean().item()

# %%
def train_model(model, optimizer, epochs=10):
    # 记录模型在训练集上的模型损失
    lossi = []
    for epoch in range(epochs):
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data['inputs'], data['labels']  # (B, T)
            optimizer.zero_grad()
            logits = model(inputs)  # (B, T, vs)
            loss = F.cross_entropy(logits.transpose(-2, -1), labels)
            lossi.append(loss.item())
            loss.backward()
            optimizer.step()
        # 评估模型，并输出结果
        stats = estimate_loss(model)
        train_loss = f'train loss {stats["train"]:.4f}'
        test_loss = f'test loss {stats["test"]:.4f}'
        print(f'epoch {epoch:>2}: {train_loss}, {test_loss}')
    return lossi

# %%
def attention(query, key, value, dropout, mask=None):
    # query, key, value: (B, T, H)
    # mask:                 (T, T)
    # output:            (B, T, H)
    B, T, H = query.shape
    scores = query @ key.transpose(-2, -1) / H ** 0.5
    if mask is not None:
        scores = scores.masked_fill(mask == 0, float('-inf'))
    w_att = F.softmax(scores, dim=-1)  # (B, T, T)
    out = w_att @ value  # (B, T, H)
    return out

# %%
class MaskedAttention(nn.Module):
    # 单向自注意力

    def __init__(self, emb_size, head_size):
        # emb_size: C, head_size: H
        super().__init__()
        self.key = nn.Linear(emb_size, head_size, bias=False)
        self.query = nn.Linear(emb_size, head_size, bias=False)
        self.value = nn.Linear(emb_size, head_size, bias=False)
        # 定义下三角矩阵
        self.register_buffer('tril', torch.tril(torch.ones(sequence_len, sequence_len)))
        self.dp = nn.Dropout(0.4)

    def forward(self, x):
        # x:   (B, T, C)
        # out: (B, T, H)
        B, T, C = x.shape
        k = self.key(x)  # (B, T, H)
        q = self.query(x)  # (B, T, H)
        v = self.value(x)  # (B, T, H)
        mask = self.tril[:T, :T]
        out = attention(q, k, v, self.dp, mask)
        return out

# %% [markdown]
# ![](./images/常见的GPT2.png)
#
# 上图中的精确图示与原图略有差异，差异的点在于第一个块的归于化层的位置，这是因为在 GPT2 的实现中归于化层在多头注意力之前，而不是严格遵循 Transformer 的架构的，这我们致敬 GPT2 ，但是本质上这对输出的内容没有显著的影响。

# %%
class MaskedMultiHeadAttention(nn.Module):

    def __init__(self, emb_size, head_size):
        super().__init__()

        # 计算单头注意力个数，貌似多头注意力的出现原因之一是为了可以使残差链接可以正常进行
        n_head = emb_size // head_size
        heads = [MaskedAttention(emb_size, head_size) for _ in range(n_head)]
        self.heads = nn.ModuleList(heads)  # 存储多个子模块，把管理交给 torch 实现
        self.proj = nn.Linear(emb_size, emb_size)
        self.dp = nn.Dropout(0.4)

    def forward(self, x):
        # x: (B, T, C)
        # out: (B, T, C)
        out = torch.concat([h(x) for h in self.heads], dim=-1)  # (B, T, C)
        out = self.dp(self.proj(out))
        return out

# %%
class FeedForward(nn.Module):
    # 前馈神经网络（其实就是多层感知器）

    def __init__(self, emb_size):
        super().__init__()

        self.ln1 = nn.Linear(emb_size, 4 * emb_size)
        self.ln2 = nn.Linear(4 * emb_size, emb_size)
        self.dp = nn.Dropout(0.4)

    def forward(self, x):
        # x: (B, T, C)
        out = F.gelu(self.ln1(x))  # (B, T, C)
        out = self.dp(self.ln2(out))  # (B, T, C)
        return out

# %%
class Block(nn.Module):

    def __init__(self, emb_size, head_size):
        super().__init__()
        self.l1 = nn.LayerNorm(emb_size)
        self.mha = MaskedMultiHeadAttention(emb_size, head_size)
        self.l2 = nn.LayerNorm(emb_size)
        self.ff = FeedForward(emb_size)

    def forward(self, x):
        # x: (B, T, C)
        # out: (B, T, C)
        x = x + self.mha(x)  # 不要使用 += 会打乱计算图！！！
        x = x + self.ff(self.l2(x))
        return x

# %%
class CharGPT(nn.Module):

    def __init__(self, vs):
        super().__init__()

        self.token_emb = nn.Embedding(vs, emb_size)
        self.pos_emb = nn.Embedding(sequence_len, emb_size)
        block = [Block(emb_size, head_size) for _ in range(n_layer)]
        self.blocks = nn.Sequential(*block)
        self.l = nn.LayerNorm(emb_size)
        self.lm = nn.Linear(emb_size, vs)

    def forward(self, x):
        # x: (B, T)
        # logits: (B, T, vs)
        B, T = x.shape
        pos = torch.arange(0, T, device=x.device, dtype=torch.long)  # 生成整数
        token_embeddings = self.token_emb(x)  # (B, T, C)
        pos_embeddings = self.pos_emb(pos)  # (B, T, C)
        h = token_embeddings + pos_embeddings  # (B, T, C)
        h = self.blocks(h)  # (B, T, C)
        logits = self.lm(self.l(h))  # (B, T, vs)
        return logits

# %%
c_model = CharGPT(len(tokenizer.char2ind)).to(device)
c_model, sum(p.numel() for p in c_model.parameters())
# Out:
# (CharGPT(
#    (token_emb): Embedding(98, 128)
#    (pos_emb): Embedding(64, 128)
#    (blocks): Sequential(
#      (0): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (1): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (2): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (3): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (4): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (5): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (6): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (7): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (8): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (9): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (10): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#      (11): Block(
#        (l1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (mha): MaskedMultiHeadAttention(
#          (heads): ModuleList(
#            (0-15): 16 x MaskedAttention(
#              (key): Linear(in_features=128, out_features=8, bias=False)
#              (query): Linear(in_features=128, out_features=8, bias=False)
#              (value): Linear(in_features=128, out_features=8, bias=False)
#              (dp): Dropout(p=0.4, inplace=False)
#            )
#          )
#          (proj): Linear(in_features=128, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#        (l2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#        (ff): FeedForward(
#          (ln1): Linear(in_features=128, out_features=512, bias=True)
#          (ln2): Linear(in_features=512, out_features=128, bias=True)
#          (dp): Dropout(p=0.4, inplace=False)
#        )
#      )
#    )
#    (l): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#    (lm): Linear(in_features=128, out_features=98, bias=True)
#  ),
#  2408290)

# %%
context = torch.tensor(tokenizer.encode('def'), device=device).unsqueeze(0)
print(''.join(tokenizer.decode(generate(c_model, context, tokenizer))))
# Out:
# def&;*7uzYG
# M&D~Y84PT.Oa -~k%ci4|PFug!;8 jMG
# eUgl<|e|>

# %%
estimate_loss(c_model)
# Out:
# {'train': 4.559240818023682, 'test': 4.554561614990234}

# %%
l = train_model(c_model, optim.AdamW(c_model.parameters(), lr=learning_rate))
# Out:
# epoch  0: train loss 0.8103, test loss 1.0632
# epoch  1: train loss 0.6371, test loss 1.0069
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 l = train_model(c_model, optim.AdamW(c_model.parameters(), lr=learning_rate))
#
# Cell In[8], line 5, in train_model(model, optimizer, epochs)
#       3 lossi = []
#       4 for epoch in range(epochs):
# ----> 5     for i, data in enumerate(train_loader, 0):
#       6         inputs, labels = data['inputs'], data['labels']  # (B, T)
#       7         optimizer.zero_grad()
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\torch\utils\data\_utils\fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\arrow_dataset.py:2863, in Dataset.__getitems__(self, keys)
#    2861 def __getitems__(self, keys: list) -> list:
#    2862     """Can be used to get a batch using a list of integers indices."""
# -> 2863     batch = self.__getitem__(keys)
#    2864     n_examples = len(batch[next(iter(batch))])
#    2865     return [{col: array[i] for col, array in batch.items()} for i in range(n_examples)]
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\arrow_dataset.py:2859, in Dataset.__getitem__(self, key)
#    2857     if self._format_type is None or self._format_type not in ("arrow", "pandas", "polars"):
#    2858         return Column(self, key)
# -> 2859 return self._getitem(key)
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\arrow_dataset.py:2841, in Dataset._getitem(self, key, **kwargs)
#    2839 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2840 pa_subtable = query_table(self._data, key, indices=self._indices)
# -> 2841 formatted_output = format_table(
#    2842     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2843 )
#    2844 return formatted_output
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\formatting\formatting.py:657, in format_table(table, key, formatter, format_columns, output_all_columns)
#     655 python_formatter = PythonFormatter(features=formatter.features)
#     656 if format_columns is None:
# --> 657     return formatter(pa_table, query_type=query_type)
#     658 elif query_type == "column":
#     659     if key in format_columns:
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\formatting\formatting.py:414, in Formatter.__call__(self, pa_table, query_type)
#     412     return self.format_column(pa_table)
#     413 elif query_type == "batch":
# --> 414     return self.format_batch(pa_table)
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\formatting\torch_formatter.py:124, in TorchFormatter.format_batch(self, pa_table)
#     122 batch = self.numpy_arrow_extractor().extract_batch(pa_table)
#     123 batch = self.python_features_decoder.decode_batch(batch)
# --> 124 batch = self.recursive_tensorize(batch)
#     125 for column_name in batch:
#     126     batch[column_name] = self._consolidate(batch[column_name])
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\formatting\torch_formatter.py:107, in TorchFormatter.recursive_tensorize(self, data_struct)
#     106 def recursive_tensorize(self, data_struct: dict):
# --> 107     return map_nested(self._recursive_tensorize, data_struct, map_list=False)
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\utils\py_utils.py:520, in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     518         batch_size = max(len(iterable) // num_proc + int(len(iterable) % num_proc > 0), 1)
#     519     iterable = list(iter_batched(iterable, batch_size))
# --> 520 mapped = [
#     521     _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     522     for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     523 ]
#     524 if batched:
#     525     mapped = [mapped_item for mapped_batch in mapped for mapped_item in mapped_batch]
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\utils\py_utils.py:521, in <listcomp>(.0)
#     518         batch_size = max(len(iterable) // num_proc + int(len(iterable) % num_proc > 0), 1)
#     519     iterable = list(iter_batched(iterable, batch_size))
#     520 mapped = [
# --> 521     _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     522     for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     523 ]
#     524 if batched:
#     525     mapped = [mapped_item for mapped_batch in mapped for mapped_item in mapped_batch]
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\utils\py_utils.py:382, in _single_map_nested(args)
#     380         return function([data_struct])[0]
#     381     else:
# --> 382         return function(data_struct)
#     383 if (
#     384     batched
#     385     and not isinstance(data_struct, dict)
#     386     and isinstance(data_struct, types)
#     387     and all(not isinstance(v, (dict, types)) for v in data_struct)
#     388 ):
#     389     return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\formatting\torch_formatter.py:104, in TorchFormatter._recursive_tensorize(self, data_struct)
#     102 elif isinstance(data_struct, (list, tuple)):
#     103     return self._consolidate([self.recursive_tensorize(substruct) for substruct in data_struct])
# --> 104 return self._tensorize(data_struct)
#
# File E:\Programming\Python\DeepLearning\venv\Lib\site-packages\datasets\formatting\torch_formatter.py:90, in TorchFormatter._tensorize(self, value)
#      87     if isinstance(value, (VideoDecoder, AudioDecoder)):
#      88         return value  # TODO(QL): set output to jax arrays ?
# ---> 90 return torch.tensor(value, **{**default_dtype, **self.torch_tensor_kwargs})
#
# KeyboardInterrupt:
